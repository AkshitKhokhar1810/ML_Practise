# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn.linear_model
import os

# %%
# Option 2: Change to script directory (if notebook differs)
os.chdir(r'C:\Users\khokh\Jupyter_Codes\Machine_learning',)  # Replace with actual path
oecd_bli = pd.read_csv('BetterLifeIndex2015.csv')
gdp_per_capita=pd.read_csv('gdp_per_capita.csv',thousands=',',delimiter='\t',encoding='latin1',na_values='n/a')

# %%
# prepare the data 
country_stats=pd.merge(oecd_bli, gdp_per_capita, on='Country')
X=np.c_[country_stats["Subject Descriptor"]]
Y=np.c_[country_stats["  Life satisfaction"]]

# %%
country_stats.plot(kind='scatter',x='Subject Descriptor',y='  Life satisfaction')
plt.show()

# %%
model = sklearn.linear_model.LinearRegression()

# %%
print('hello world')
# Out:
# hello world

# %%
# !git add "Basic Model run.ipynb"
# !git commit -m "adding hello world to the code"
# !git push origin feature/Baisc_Model
# Out:
# warning: in the working copy of 'Basic Model run.ipynb', LF will be replaced by CRLF the next time Git touches it
# [feature/Baisc_Model 4e5bd82] adding hello world to the code
#  1 file changed, 14 insertions(+), 12 deletions(-)
# To https://github.com/AkshitKhokhar1810/ML_Practise.git
#    20034e2..4e5bd82  feature/Baisc_Model -> feature/Baisc_Model
